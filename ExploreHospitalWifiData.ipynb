# %%
# %pylab
import pandas as pd
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_pickle("./wifi_data.pkl")
data.tail()
# Out:
#                     BSSID             SSID  anqpDomainId  beaconInterval  \
# 270836  14:6b:9c:60:41:e7  YICarCam_6041E7             0             100
# 270837  94:e3:6d:82:1d:b5    ELRSSID821DB5             0             100
# 270838  92:54:cd:0c:82:b8  2PlusPortableAP             0             100
# 270839  14:6b:9c:60:41:e7  YICarCam_6041E7             0             100
# 270840  94:e3:6d:82:1d:b5    ELRSSID821DB5             0             100
#
#                                         capabilities  carrierApEapType  \
# 270836            [WPA2-PSK-CCMP][WPA-PSK-CCMP][ESS]                -1
# 270837  [WPA2-PSK-CCMP+TKIP][WPA-PSK-CCMP+TKIP][ESS]                -1
# 270838                          [WPA2-PSK-CCMP][ESS]                -1
# 270839            [WPA2-PSK-CCMP][WPA-PSK-CCMP][ESS]                -1
# 270840  [WPA2-PSK-CCMP+TKIP][WPA-PSK-CCMP+TKIP][ESS]                -1
#
#         centerFreq0  centerFreq1  channelWidth  distanceCm  \
# ...

# %%
start_time = data.timestamp.min()
data.timestamp = data.timestamp.apply(lambda x: x - start_time)
# data = data.sort_values('timestamp')
data.head()
# Out:
#                BSSID   SSID  anqpDomainId  beaconInterval  \
# 0  6c:f3:7f:18:a8:29  marta             0             100
# 1  6c:f3:7f:18:ae:e1  marta             0             100
# 2  6c:f3:7f:e0:9b:18                    0             100
# 3  6c:f3:7f:18:aa:71  marta             0             100
# 4  24:de:c6:d0:78:d8                    0             100
#
#                          capabilities  carrierApEapType  centerFreq0  \
# 0  [WPA2-PSK-TKIP][WPA-PSK-TKIP][ESS]                -1            0
# 1  [WPA2-PSK-TKIP][WPA-PSK-TKIP][ESS]                -1            0
# 2                [WPA2-EAP-CCMP][ESS]                -1         5270
# 3  [WPA2-PSK-TKIP][WPA-PSK-TKIP][ESS]                -1            0
# 4                [WPA2-EAP-CCMP][ESS]                -1         5190
#
#    centerFreq1  channelWidth  distanceCm          ...                    seen  \
# 0            0             0          -1          ...           1584869189863
# ...

# %%
data.timestamp.max()
# Out:
# 4053334272
